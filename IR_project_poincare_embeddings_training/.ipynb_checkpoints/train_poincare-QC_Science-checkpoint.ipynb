# %%
import os
import logging
import numpy as np

from gensim.models.poincare import PoincareModel, PoincareKeyedVectors, PoincareRelations
from gensim.test.utils import datapath

logging.basicConfig(level=logging.INFO)

# %%
file_path = 'data/course_taxonomy.links.tsv'

relations = PoincareRelations(file_path=file_path, delimiter='\t')
model = PoincareModel(train_data=relations)
# Out:
# INFO:gensim.models.poincare:loading relations from train data..
# INFO:gensim.models.poincare:loaded 1056 relations from train data, 399 nodes

# %%
model = PoincareModel(train_data=relations, size=20, burn_in=10,epsilon=1e-06,negative=20) # train awith 10 burn-in epochs
model.train(epochs=300, print_every=100)
# Out:
# INFO:gensim.models.poincare:loading relations from train data..
# INFO:gensim.models.poincare:loaded 1056 relations from train data, 399 nodes
# INFO:gensim.models.poincare:training model of size 20 with 1 workers on 1056 relations for 300 epochs and 10 burn-in epochs, using lr=0.10000 burn-in lr=0.01000 negative=20
# INFO:gensim.models.poincare:starting burn-in (10 epochs)----------------------------------------
# INFO:gensim.models.poincare:training on epoch 1, examples #990-#1000, loss: 30.18
# INFO:gensim.models.poincare:time taken for 1000 examples: 0.77 s, 1297.37 examples / s
# INFO:gensim.models.poincare:training on epoch 2, examples #990-#1000, loss: 29.49
# INFO:gensim.models.poincare:time taken for 1000 examples: 0.54 s, 1866.55 examples / s
# INFO:gensim.models.poincare:training on epoch 3, examples #990-#1000, loss: 28.88
# INFO:gensim.models.poincare:time taken for 1000 examples: 0.50 s, 1987.95 examples / s
# ...

# %%
model.save("taxonomy_embedding_20.pkl")
