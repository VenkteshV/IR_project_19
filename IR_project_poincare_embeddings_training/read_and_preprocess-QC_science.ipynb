# %%
from gzip import open as gopen

import pandas as pd
from pprint import pprint



def read_and_preprocess():
    science_data = pd.read_csv("train_QC_data.csv")
    science_data_additional = pd.read_csv("val_QC_data.csv")
    science_data_test = pd.read_csv("test_QC_data.csv")

    combined = [science_data,science_data_additional,science_data_test]
    science_data = pd.concat(combined)
    taxonomy = science_data["QCLabel"]
    taxonomy_list = list(set(taxonomy.values.tolist()))
    print(len(taxonomy_list))
    cleaned_taxonomy = []
    for value in taxonomy_list:
        value = value.split("_")
        value = [val.lower() for val in value]
        value="\t".join(value)
        cleaned_taxonomy.append(value)
    merged_syllabi = []
#     for syllabus in cleaned_taxonomy:
#       split_syllabus = syllabus.split("\t")
#       merged_syllabus = '\t'.join(split_syllabus[2:])
#       merged_syllabi.append(merged_syllabus)
    return cleaned_taxonomy








taxonomy = read_and_preprocess()
# Out:
# 420

# %%
taxonomy
# Out:
# ['energy\tmeasurement\tunit',
#  'matter\tproperties of objects\ttemp',
#  'life\tfunctions\tfeatures and functions\tcellbio\tstruct\tvacuole',
#  'earth\thuman impacts\tres\trenewable',
#  'earth\tgeo\trock\tident',
#  'life\tcycle\tplant span',
#  'science\tinference\thyp',
#  'matter\tproperties of material\tdensity',
#  'earth\tinner\tplatevolcanoe',
#  'matter\tproperties of material\treflect',
#  'life\thealth\tdiesease',
#  'energy\telec\telectromagnets',
#  'earth\tgeo\tformations\tearth\tweather\terosion\terosion',
#  'for\tbalanced',
#  'celestial\tchange of statemology',
#  'life\tcycle\tanimal cycle\tamphib',
#  'life\tenvironment and adaptation\tanimal adaptations\tstruct\tcamo',
#  'matter\tproperties of material\tclass',
#  'life\tfunctions\tfeatures and functions\tplant\treproduction',
#  'life\tfunctions\tfeatures and functions\tanimal\tlocomotion',
#  'life\tfunctions\tfeatures and functions\tcellbio\torg\ttissues',
#  'work\tforces and friction and objects',
#  'life\tinterdependency\tsuccession',
#  'energy\ttherm\theatcoolprob',
#  'matter\tproperties of material\tsolubility',
#  'matter\tproperties of objects\tvol',
#  'life\tinterdependency\tfoodchain\tplant producers',
#  'energy\tlight\telectromagnetic spectrum',
#  'earth\tweather\twater cycle\tprec',
#  'earth\tgeo\tfossils\trocktypes',
#  'energy\tsound\tdoppler',
#  'life\tfunctions\tfeatures and functions\tanimal\tnervous system ',
#  'celestial\tapparentmotion celestial\tcycles',
#  'celestial\ttimemotion',
#  'energy\tforms\tlight',
#  'work\tforces and objects',
#  'matter\tmixtures\tsepcompounds',
#  'life\tfunctions\tfeatures and functions\tcellbio\tunimulticell',
#  'earth\tgeo\tformations\tearth\tinner\tgeneric plate',
#  'earth\tgeo\trock\tchange',
#  'for\tmotprob',
#  'life\tcycle\tanimal cycle\tinsect',
#  'other\thist\tinvent',
#  'life\tfunctions\tfeatures and functions\tplant\tvascular',
#  'matter\tchemistry\tperiodic table',
#  'energy\tlight\tgenericprop',
#  'earth\tweather',
#  'earth\thuman impacts\tres\tnatgas',
#  'life\tfunctions\tfeatures and functions\tcellbio\tstruct\tendoret',
#  'energy\tpotentialkinetic',
#  'energy\tlight\tabsorption',
#  'other\thist',
#  'life\tcycle\tanimal cycle\tmammal',
#  'life\tenvironment and adaptation\tanimal adaptations\tstruct\thunting',
#  'life\thealth\tdiesease\tprevention',
#  'energy\tsound\tgenerate',
#  'life\tenvironment and adaptation\tnatsel',
#  'matter\tproperties of material\tmag',
#  'energy\tthermal conductivity\tconvect',
#  'life\tfunctions\tfeatures and functions\tcellbio\tproteins',
#  'life\tfunctions\tfeatures and functions\tcellbio\tstruct\tcytoplcytoskel',
#  'earth\tweather\tdef',
#  'matter\tmeasurement\tunit\ttemp',
#  'earth\tweather\twater cycle\tprec\tearth\tweather\twater cycle\tevapcond',
#  'earth\tgeo\trock\tinge',
#  'science\tgraph',
#  'other\tengineering',
#  'earth\thuman impacts\tres\toil',
#  'life\tenvironment and adaptation\tanimal adaptations\tbehav\tnestbldg',
#  'life\tfunctions\tfeatures and functions\tanimal\texcret',
#  'science\tinference\tquestioning',
#  'matter\tchange of state\tevaporation',
#  'energy\tlight\treflect',
#  'life\thealth\tdiesease\tinfect',
#  'celestial\tfeatures\tother',
#  'life\tfunctions\tenvironmental response\tplant',
#  'matter\tproperties of material\tcol',
#  'earth\tgeo\tformations',
#  'life\tenvironment and adaptation\tcomp',
#  'matter\tmixtures\tcompounds',
#  'earth\tinner\tplate',
#  'earth\thuman impacts\twhat\tair pollution',
#  'life\tenvironment and adaptation\tanimal adaptations\tbehav',
#  'energy\telec\tcircuits',
#  'science\tinference',
#  'earth\tgeo\tformations\tearth\tweather\terosion',
#  'energy\twaves\ttypes of motion',
#  'energy\tsound\tspeed',
#  'life\tenvironment and adaptation\tadap',
#  'earth\tgeo\tfossils\tloc',
#  'celestial\tdistances',
#  'for\tnewton\t3rd',
#  'matter\tmixtures',
#  'earth\thuman impacts\twhat\tpollution\twater',
#  'energy\tthermal conductivity\tradiation',
#  'science\tinference\texprun',
#  'matter\tmeasurement\tunit\tmass',
#  'life\tfunctions\tfeatures and functions\tanimal\tendocrine',
#  'life\tfunctions\tfeatures and functions\tplant\troot',
#  'life\tfunctions\tfeatures and functions\tanimal\tdigest',
#  'celestial\tfeatures\tcomet',
#  'celestial\tspaceex\tvehicle',
#  'celestial\tcycles',
#  'life\tfunctions\tenvironmental conditions\tplant',
#  'for\tmech\tsimplemachines',
#  'celestial\tfeatures\tsolarsystems',
#  'force\tnewton\tfirst',
#  'science\tinference\tformlaws',
#  'life\tfunctions\tfeatures and functions\tcellbio\tmeiosis',
#  'energy\tforms\tchem',
#  'life\tfunctions\tfeatures and functions\tcellbio\tcelltheory',
#  'matter\tchemistry\tconservation of mass of mass',
#  'saf\tequip',
#  'earth\thuman impacts\twhat\tpollution\tsoil',
#  'life\tfunctions\tfeatures and functions\tplant',
#  'earth\tweather\tmeasurement\tprecipitation',
#  'life\tfunctions\tfeatures and functions\tcellbio\tmitosis',
#  'earth\tweather\tairmass',
#  'matter\tproperties of material\tflammable',
#  'energy\telec\tohmslaw',
#  'earth\tweather\twater cycle\tevapcond',
#  'earth\tgeo\tformations\tearth\tweather\terosion\tdeposition',
#  'life\tinterdependency\tabiotic',
#  'life\thealth\tdiesease\tnoninfect\tgenetic',
#  'earth\tinner\tearthquakes',
#  'earth\thuman impacts\tres\tnuclear',
#  'life\tenvironment and adaptation\tanimal adaptations\tbehav\thunt',
#  'earth\thuman impacts\tres\tmining',
#  'matter\tchem\tchemreact',
#  'life\tfunctions\tfunct\tanimaless',
#  'life\tfunctions\tfeatures and functions\tcellbio\tplantcell',
#  'matter\tproperties of material\teleccond',
#  'earth\tgeo\tfossils\tindex',
#  'life\tfunctions\tfeatures and functions\tplant\tstem',
#  'life\tinterdependency\tfoodchain\tsun',
#  'matter\tfund',
#  'for\tairresistance',
#  'earth\touter\tlith',
#  'matter\tproperties of material\tthermcond',
#  'energy\telec\tcircuits\tenergy\tdevices',
#  'for\tmech\tgeneral',
#  'celestial\tlunar phases',
#  'earth\tweather\twater cycle',
#  'matter\tchange of state\tcondensing',
#  'science\tinference\texperiment design',
#  'earth\tgeo\tformations\tearth\tinner\tplatevolcanoe',
#  'energy\telec\telectromagnets\tenergy\tdevices',
#  'celestial\tfeatures\tgalactic',
#  'energy\twaves\tgenericprop',
#  'life\tfunctions\tfeatures and functions\tcellbio\tstruct\tlyso',
#  'earth\tweather\twater cycle\tsun\tearth\tweather\twater cycle\tevapcond',
#  'earth\thuman impacts\twhat\tglobalwarming',
#  'life\tinterdependency',
#  'life\tinterdependency\tfoodchain\tdecomposer',
#  'matter\tchemistry\tconservation of mass',
#  'celestial\tbrightness',
#  'earth\tweather\twind',
#  'earth\thuman impacts\twhat\trecy',
#  'life\tfunctions\tfeatures and functions\tcellbio\tstruct\tmito',
#  'energy conversion\tenergy\tdevices',
#  'work\tforces and friction',
#  'science\tinference\tinference',
#  'life\tfunctions\tfunct',
#  'life\tfunctions\tfeatures and functions\tcellbio\tstruct\tchromosome',
#  'matter\tproperties of material\ttransparent',
#  'matter\tproperties of material\ttaste',
#  'life\tfunctions\tfeatures and functions\tanimal\tskinintergum',
#  'life\tfunctions\tfeatures and functions\tcellbio\torg',
#  'for\tpower',
#  'energy\tforms\tmech',
#  'other\tdevice',
#  'matter\tproperties of material',
#  'earth\tinner\tinternal heat',
#  'matter\tstates\tsolid',
#  'life\tfunctions\tenvironmental conditions\tanimal',
#  'earth\thuman impacts\twhat\thabitat destruction',
#  'energy\tconservation',
#  'life\tfunctions\tfeatures and functions\tanimal\treproduction',
#  'earth\tweather\twater cycle\tsun',
#  'life\tinterdependency\tfoodchain\tdef',
#  'life\treproduction\tdna inheritance\tinheritance',
#  'energy\tlight\tspeed',
#  'matter\tchange of state\tmelting',
#  'celestial\tfeatures\tmoons',
#  'earth\tweather\terosion\terosion',
#  'matter\tmixtures\tsephetero',
#  'science\tinference\tverification',
#  'energy\tdevices',
#  'for\tnewton\t2nd',
#  'life\tfunctions\tfeatures and functions\tplant\tphotosynth',
#  'for\tpressure',
#  'earth\tweather\twater cycle\tgroundwater',
#  'life\tfunctions\tfeatures and functions\tanimal\tcirculatory',
#  'life',
#  'celestial\teclipse',
#  'life\tfunctions\tfeatures and functions\tcellbio\tstruct\tribosomes',
#  'life\tfunctions\tfeatures and functions\tcellbio',
#  'matter\tenveff\tlight',
#  'earth\tweather\tgeoeff',
#  'energy\tforms\tsound',
#  'earth\thuman impacts\twhat\tpollution',
#  'life\tinterdependence\tecological features',
#  'celestial\tsizes',
#  'energy\telec\tgenerate\tenergy\tdevices',
#  'energy\tlight\tscattering',
#  'life\treproduction\tdna inheritance\tdomrecess',
#  'life\tfunctions\tfeatures and functions\tcellbio\treprodother',
#  'matter\tproperties of material\thard',
#  'matter\tchange of state\tboiling',
#  'matter\tchemistry\tacids and bases',
#  'earth\tweather\terosion',
#  'matter\tchanges\tphysical',
#  'earth\tweather\terosion\tdeposition',
#  'forces\tmagnetism',
#  'earth\tsoil\tecosystem',
#  'matter\tproperties of objects\tshape',
#  'life\tfunctions\tenvironmental response\tanimal',
#  'earth\tinner\tgeneric plate',
#  'matter\tmeasurement\tinstruments\tclock',
#  'matter\tproperties of objects\tsize',
#  'life\tfunctions\tfeatures and functions\tcellbio\tstruct\tcellmemb',
#  'matter\tproperties of objects\tmass',
#  'matter\tmeasurement\tunit\ttime',
#  'matter\tproperties of material\tflex',
#  'matter\tchanges\tchemical',
#  'matter\tmixtures\talloys',
#  'science\tinference\tobservation',
#  'force\tlift',
#  'life\tfunctions\tfeatures and functions\tanimal\tnervous system',
#  'matter\tproperties of material\tbouy',
#  'energy\tsound\tfreqwl',
#  'life\tcycle\tgrowth\tproc',
#  'matter\tchemistry\tatomic',
#  'earth\tgeo\tfossils\tspecies',
#  'life\tfunctions\tfeatures and functions\tanimal\tbreathing',
#  'matter\tmeasurement\tunit\tph',
#  'life\tenvironment and adaptation\tanimal adaptations\tstruct\tfur',
#  'life\tenvironment and adaptation\tadap\tplant',
#  'earth\tweather\tbaropressure',
#  'matter\tmixtures\theterogeneous',
#  'celestial\tfeatures\tnebulae',
#  'life\tenvironment and adaptation\tanimal adaptations\tstruct\tfat',
#  'earth\tinner\tcmc\tcrust',
#  'life\tenvironment and adaptation\tanimal adaptations\tbehav\tcomm',
#  'celestial\tfeatures\tstellar',
#  'enery\tinteraction',
#  'life\tfunctions\tfeatures and functions\tcellbio\tstruct\tchloroplast',
#  'life\tenvironment and adaptation\tanimal adaptations\tbehaviours\thibernation',
#  'life\tnitrogen cyclele',
#  'matter\tstates\tgas',
#  'matter\tmeasurement\tunit\tdist',
#  'science\tinference\twhattesting',
#  'energy\tlight\tcolincol',
#  'earth\tweather\tmeas',
#  'earth\tweather\tclimate',
#  'matter\tmeasurement\tinstruments\tbalance',
#  'life\thealth\tgoodhabits',
#  'celestial\tgravitational pull',
#  'earth\tsoil\tcomponents',
#  'earth\touter\thydro',
#  'life\tfunctions\tfeatures and functions\tanimal\tsenses',
#  'science\tinference\tbias',
#  'life\tfunctions\tenvironmental conditions',
#  'energy\tsound\tgenericprop',
#  'earth\tcarddirection',
#  'matter\tproperties of material\tdurability',
#  'earth\thuman impacts\tres',
#  'matter\tproperties of material\todor',
#  'earth\touter\tatmosphere',
#  'life\tcarbon cycle',
#  'for',
#  'earth\tgeo\tfossils',
#  'life\treproduction\tdna inheritance\tacquired',
#  'life\tfunctions\tfeatures and functions\tanimal\tskeletal',
#  'earth\tweather\tclouds\tearth\tweather\twater cycle\tevapcond',
#  'matter\tchange of state\tfreezing',
#  'life\treproduction\tdna inheritance\tmutation',
#  'life\tclassification',
#  'life\tcycle\tanimal cycle',
#  'life\tlivingnonliving',
#  'energy\twaves\tfreqwl',
#  'earth\tweather\textreme',
#  'life\tfunctions\tfeatures and functions\tplant\treproduction\tseeddisp',
#  'life\tfunctions\tfeatures and functions\tplant\ttranspir',
#  'life\tcycle\tgrowth\tdef',
#  'earth\thuman impacts\tres\tfossilfuel',
#  'energy\tforms\theat',
#  'matter\tproperties of material\tluster',
#  'energy\twaves\ttransfereng',
#  'saf\tproc',
#  'life\tfunctions\tfeatures and functions\tcellbio\tstruct\tnucleus',
#  'energy\tsound\tamplitude',
#  'matter\tproperties of objects\ttext',
#  'earth\tweather\tclouds',
#  'life\tfunctions\tfeatures and functions\tanimal cell',
#  'matter\tchange of state\ttemp',
#  'earth\thuman impacts\tres\thydro',
#  'science\tsources',
#  'life\tfunctions\tfunct\tplantess',
#  'celestial\tfeatures\tmeteor',
#  'life\treproduction\tdna inheritance\tgendrift',
#  'life\tenvironment and adaptation\tanimal adaptations\tbehav\tmigr',
#  'celestial\tapparentmotion',
#  'life\tcycle\tanimal cycle\tbird',
#  'celestial\tspaceex\thuman',
#  'life\tmeastools',
#  'life\tfunctions\tfeatures and functions\tanimal\tmuscular',
#  'earth\thuman impacts\tres\tsoil',
#  'force\tgravity',
#  'celestial\tinstruments',
#  'matter\tchem\telements vs molecules and compounds',
#  'earth\thuman impacts\tres\ttrees',
#  'energy\tthermal conductivity',
#  'earth\tgeo\tmineral\tformation',
#  'life\tcycle\tanimal cycle\treptile',
#  'energy conversion',
#  'earth\tgeo\trock',
#  'energy\twaves\treflection',
#  'matter\tproperties of objects\tdensity',
#  'life\tfunctions\tfeatures and functions',
#  'earth\tinner\tcmc\tmantle',
#  'matter\tproperties of objects',
#  'celestial\tfeatures\tblackhole',
#  'life\thealth\tdiesease\tpandemicepidemic',
#  'life\tcycle\tgrowth',
#  'earth\touter\tatmosphere\tearth\tweather\twater',
#  'energy\telec\tgenerate',
#  'life\treproduction\tsexasex\tasex',
#  'science\tinference\tsamplesize',
#  'life\tinterdependency\tfoodchain\tconsumers',
#  'matter\tmeasurement\tinstruments\tcompass',
#  'earth\tweather\tjetstream',
#  'life\tinterdependency\tfoodchain ',
#  'life\tfunctions\tfeatures and functions\tcellbio\tstruct\tcellwall',
#  'science\tmodels',
#  'life\tfunctions\tfeatures and functions\tcellbio\treprod',
#  'life\tenvironment and adaptation\tadap\tanimal',
#  'matter\tmeasurement\tunit',
#  'earth\thuman impacts\tres\twind',
#  'matter\tmeasurement\tinstruments\tmagnify',
#  'life\thealth\tdiesease\tnoninfect',
#  'energy\tsound\techo',
#  'life\textinction\tmassex',
#  'matter\tstates\tliquid',
#  'celestial\ttides',
#  'life\tfunctions\tfeatures and functions\tcellbio\torg\tcells',
#  'energy\tdevices\theat form',
#  'life\tfunctions\tfeatures and functions\tcellbio\torg\torgsystems',
#  'earth\tweather\tmodels',
#  'earth\tgeo\tmineral',
#  'science\tinference\tinference ',
#  'matter\tchem\tendoexo',
#  'energy\tlight\trefract',
#  'matter\tchange of state\tevap',
#  'life\tenvironment and adaptation\tanimal adaptations\tstruct',
#  'earth\thuman impacts\twhat\tconserve',
#  'science\tinference\tsteps',
#  'life\tcycle\tplant  cycle',
#  'matter\tmeasurement\tunit\tvol',
#  'life\tinterdependency\trelspecies',
#  'life\tfunctions\tfunct\tanimaless\tnutrition',
#  'life\tfunctions\tfeatures and functions\tanimal',
#  'science\tinference\treport',
#  'earth\tweather\tmeasurement\twindspeed',
#  'energy\tforms',
#  'force\twork',
#  'life\tinterdependency\tfoodchain',
#  'earth\thuman impacts\tres\tsolar',
#  'earth\thuman impacts\tres\twater',
#  'energy\telec\tcond',
#  'celestial\tfeatures\tplanet',
#  'life\tenvironment and adaptation\tanimal adaptations\tstruct\tsenses',
#  'life\tenvironment and adaptation\tplant',
#  'earth\thuman impacts\tres\tcoal',
#  'earth\tweather\terosion\tweathering',
#  'matter\tstates',
#  'life\treproduction\tsexasex\tsex',
#  'life\tfunctions\tfeatures and functions\tplant\tleaf',
#  'matter\tmeasurement\tinstruments\tgraduated',
#  'matter\tproperties of material\tspecificheat',
#  'life\tfunctions\tfeatures and functions\tcellbio\tgeneexpr',
#  'life\treproduction',
#  'energy\tforms\telec',
#  'life\tfunctions\tfeatures and functions\tcellbio\trespir',
#  'earth\tinner\tplate\tmountain form',
#  'earth\tinner\tcmc\tcore',
#  'life\tfunctions\tfeatures and functions\tcellbio\torg\torgans',
#  'for\tmomentum',
#  'earth\tgeo\tmineral\tident',
#  'matter\tenveff\ttemp',
#  'earth\tinner\tplate\tcontdrift',
#  'earth\tgeo\trock\tsed',
#  'earth\thuman impacts\tres\tgeothermal',
#  'other\tmanufacture',
#  'other\tinstructions',
#  'energy\tthermal conductivity\tconduct',
#  'force\tvelocity',
#  'other',
#  'life\tenvironment and adaptation\tanimal adaptations\tstruct\tdefense',
#  'life\treproduction\tdna inheritance\tdna',
#  'matter\tmeasurement\tinstruments\ttherm',
#  'life\treproduction\tdna inheritance\tselbreeding',
#  'matter\tmeasurement\tunit\tdensity',
#  'life\tfunctions\tenvironmental response',
#  'life\tinterdependency\tpopdyn',
#  'matter\tmeasurement\tinstruments\truler',
#  'life\treproduction\tcompetition',
#  'energy\tconversion\tinefficiency',
#  'other\tcuriosity',
#  'earth\thuman impacts\twhat',
#  'earth\tgeo\trock\tmeta',
#  'life\tfunctions\tfeatures and functions\tanimal\timmune',
#  'earth\thuman impacts\twhat\tpopdest',
#  'science\tinference\ttestable',
#  'life\tfunctions\tfeatures and functions\tcellbio\tstruct\tgolgi',
#  'earth\tgeo\thistory',
#  'life\tfunctions\tfeatures and functions\tanimal\tfeedback',
#  'celestial\torbit',
#  'celestial\tdistances\tunits',
#  'matter\tmeasurement\tinstruments']

# %%
edges = []
nodes = set()
for index,tax in enumerate(taxonomy):
    phrases = tax.split("\t")
    for i,val in enumerate(phrases):
        if(i+1<len(phrases)):
            parent=val
            nodes.add(val)
            child = (phrases[i+1])
            nodes.add(child)
            edges.append( (child,parent) )
        else:
            nodes.add(val)
    if index<=10:print(tax.rstrip("\n"))
# Out:
# energy	measurement	unit
# matter	properties of objects	temp
# life	functions	features and functions	cellbio	struct	vacuole
# earth	human impacts	res	renewable
# earth	geo	rock	ident
# life	cycle	plant span
# science	inference	hyp
# matter	properties of material	density
# earth	inner	platevolcanoe
# matter	properties of material	reflect
# life	health	diesease

# %%
edges
# Out:
# [('measurement', 'energy'),
#  ('unit', 'measurement'),
#  ('properties of objects', 'matter'),
#  ('temp', 'properties of objects'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('struct', 'cellbio'),
#  ('vacuole', 'struct'),
#  ('human impacts', 'earth'),
#  ('res', 'human impacts'),
#  ('renewable', 'res'),
#  ('geo', 'earth'),
#  ('rock', 'geo'),
#  ('ident', 'rock'),
#  ('cycle', 'life'),
#  ('plant span', 'cycle'),
#  ('inference', 'science'),
#  ('hyp', 'inference'),
#  ('properties of material', 'matter'),
#  ('density', 'properties of material'),
#  ('inner', 'earth'),
#  ('platevolcanoe', 'inner'),
#  ('properties of material', 'matter'),
#  ('reflect', 'properties of material'),
#  ('health', 'life'),
#  ('diesease', 'health'),
#  ('elec', 'energy'),
#  ('electromagnets', 'elec'),
#  ('geo', 'earth'),
#  ('formations', 'geo'),
#  ('earth', 'formations'),
#  ('weather', 'earth'),
#  ('erosion', 'weather'),
#  ('erosion', 'erosion'),
#  ('balanced', 'for'),
#  ('change of statemology', 'celestial'),
#  ('cycle', 'life'),
#  ('animal cycle', 'cycle'),
#  ('amphib', 'animal cycle'),
#  ('environment and adaptation', 'life'),
#  ('animal adaptations', 'environment and adaptation'),
#  ('struct', 'animal adaptations'),
#  ('camo', 'struct'),
#  ('properties of material', 'matter'),
#  ('class', 'properties of material'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('plant', 'features and functions'),
#  ('reproduction', 'plant'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('animal', 'features and functions'),
#  ('locomotion', 'animal'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('org', 'cellbio'),
#  ('tissues', 'org'),
#  ('forces and friction and objects', 'work'),
#  ('interdependency', 'life'),
#  ('succession', 'interdependency'),
#  ('therm', 'energy'),
#  ('heatcoolprob', 'therm'),
#  ('properties of material', 'matter'),
#  ('solubility', 'properties of material'),
#  ('properties of objects', 'matter'),
#  ('vol', 'properties of objects'),
#  ('interdependency', 'life'),
#  ('foodchain', 'interdependency'),
#  ('plant producers', 'foodchain'),
#  ('light', 'energy'),
#  ('electromagnetic spectrum', 'light'),
#  ('weather', 'earth'),
#  ('water cycle', 'weather'),
#  ('prec', 'water cycle'),
#  ('geo', 'earth'),
#  ('fossils', 'geo'),
#  ('rocktypes', 'fossils'),
#  ('sound', 'energy'),
#  ('doppler', 'sound'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('animal', 'features and functions'),
#  ('nervous system ', 'animal'),
#  ('apparentmotion celestial', 'celestial'),
#  ('cycles', 'apparentmotion celestial'),
#  ('timemotion', 'celestial'),
#  ('forms', 'energy'),
#  ('light', 'forms'),
#  ('forces and objects', 'work'),
#  ('mixtures', 'matter'),
#  ('sepcompounds', 'mixtures'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('unimulticell', 'cellbio'),
#  ('geo', 'earth'),
#  ('formations', 'geo'),
#  ('earth', 'formations'),
#  ('inner', 'earth'),
#  ('generic plate', 'inner'),
#  ('geo', 'earth'),
#  ('rock', 'geo'),
#  ('change', 'rock'),
#  ('motprob', 'for'),
#  ('cycle', 'life'),
#  ('animal cycle', 'cycle'),
#  ('insect', 'animal cycle'),
#  ('hist', 'other'),
#  ('invent', 'hist'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('plant', 'features and functions'),
#  ('vascular', 'plant'),
#  ('chemistry', 'matter'),
#  ('periodic table', 'chemistry'),
#  ('light', 'energy'),
#  ('genericprop', 'light'),
#  ('weather', 'earth'),
#  ('human impacts', 'earth'),
#  ('res', 'human impacts'),
#  ('natgas', 'res'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('struct', 'cellbio'),
#  ('endoret', 'struct'),
#  ('potentialkinetic', 'energy'),
#  ('light', 'energy'),
#  ('absorption', 'light'),
#  ('hist', 'other'),
#  ('cycle', 'life'),
#  ('animal cycle', 'cycle'),
#  ('mammal', 'animal cycle'),
#  ('environment and adaptation', 'life'),
#  ('animal adaptations', 'environment and adaptation'),
#  ('struct', 'animal adaptations'),
#  ('hunting', 'struct'),
#  ('health', 'life'),
#  ('diesease', 'health'),
#  ('prevention', 'diesease'),
#  ('sound', 'energy'),
#  ('generate', 'sound'),
#  ('environment and adaptation', 'life'),
#  ('natsel', 'environment and adaptation'),
#  ('properties of material', 'matter'),
#  ('mag', 'properties of material'),
#  ('thermal conductivity', 'energy'),
#  ('convect', 'thermal conductivity'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('proteins', 'cellbio'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('struct', 'cellbio'),
#  ('cytoplcytoskel', 'struct'),
#  ('weather', 'earth'),
#  ('def', 'weather'),
#  ('measurement', 'matter'),
#  ('unit', 'measurement'),
#  ('temp', 'unit'),
#  ('weather', 'earth'),
#  ('water cycle', 'weather'),
#  ('prec', 'water cycle'),
#  ('earth', 'prec'),
#  ('weather', 'earth'),
#  ('water cycle', 'weather'),
#  ('evapcond', 'water cycle'),
#  ('geo', 'earth'),
#  ('rock', 'geo'),
#  ('inge', 'rock'),
#  ('graph', 'science'),
#  ('engineering', 'other'),
#  ('human impacts', 'earth'),
#  ('res', 'human impacts'),
#  ('oil', 'res'),
#  ('environment and adaptation', 'life'),
#  ('animal adaptations', 'environment and adaptation'),
#  ('behav', 'animal adaptations'),
#  ('nestbldg', 'behav'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('animal', 'features and functions'),
#  ('excret', 'animal'),
#  ('inference', 'science'),
#  ('questioning', 'inference'),
#  ('change of state', 'matter'),
#  ('evaporation', 'change of state'),
#  ('light', 'energy'),
#  ('reflect', 'light'),
#  ('health', 'life'),
#  ('diesease', 'health'),
#  ('infect', 'diesease'),
#  ('features', 'celestial'),
#  ('other', 'features'),
#  ('functions', 'life'),
#  ('environmental response', 'functions'),
#  ('plant', 'environmental response'),
#  ('properties of material', 'matter'),
#  ('col', 'properties of material'),
#  ('geo', 'earth'),
#  ('formations', 'geo'),
#  ('environment and adaptation', 'life'),
#  ('comp', 'environment and adaptation'),
#  ('mixtures', 'matter'),
#  ('compounds', 'mixtures'),
#  ('inner', 'earth'),
#  ('plate', 'inner'),
#  ('human impacts', 'earth'),
#  ('what', 'human impacts'),
#  ('air pollution', 'what'),
#  ('environment and adaptation', 'life'),
#  ('animal adaptations', 'environment and adaptation'),
#  ('behav', 'animal adaptations'),
#  ('elec', 'energy'),
#  ('circuits', 'elec'),
#  ('inference', 'science'),
#  ('geo', 'earth'),
#  ('formations', 'geo'),
#  ('earth', 'formations'),
#  ('weather', 'earth'),
#  ('erosion', 'weather'),
#  ('waves', 'energy'),
#  ('types of motion', 'waves'),
#  ('sound', 'energy'),
#  ('speed', 'sound'),
#  ('environment and adaptation', 'life'),
#  ('adap', 'environment and adaptation'),
#  ('geo', 'earth'),
#  ('fossils', 'geo'),
#  ('loc', 'fossils'),
#  ('distances', 'celestial'),
#  ('newton', 'for'),
#  ('3rd', 'newton'),
#  ('mixtures', 'matter'),
#  ('human impacts', 'earth'),
#  ('what', 'human impacts'),
#  ('pollution', 'what'),
#  ('water', 'pollution'),
#  ('thermal conductivity', 'energy'),
#  ('radiation', 'thermal conductivity'),
#  ('inference', 'science'),
#  ('exprun', 'inference'),
#  ('measurement', 'matter'),
#  ('unit', 'measurement'),
#  ('mass', 'unit'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('animal', 'features and functions'),
#  ('endocrine', 'animal'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('plant', 'features and functions'),
#  ('root', 'plant'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('animal', 'features and functions'),
#  ('digest', 'animal'),
#  ('features', 'celestial'),
#  ('comet', 'features'),
#  ('spaceex', 'celestial'),
#  ('vehicle', 'spaceex'),
#  ('cycles', 'celestial'),
#  ('functions', 'life'),
#  ('environmental conditions', 'functions'),
#  ('plant', 'environmental conditions'),
#  ('mech', 'for'),
#  ('simplemachines', 'mech'),
#  ('features', 'celestial'),
#  ('solarsystems', 'features'),
#  ('newton', 'force'),
#  ('first', 'newton'),
#  ('inference', 'science'),
#  ('formlaws', 'inference'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('meiosis', 'cellbio'),
#  ('forms', 'energy'),
#  ('chem', 'forms'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('celltheory', 'cellbio'),
#  ('chemistry', 'matter'),
#  ('conservation of mass of mass', 'chemistry'),
#  ('equip', 'saf'),
#  ('human impacts', 'earth'),
#  ('what', 'human impacts'),
#  ('pollution', 'what'),
#  ('soil', 'pollution'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('plant', 'features and functions'),
#  ('weather', 'earth'),
#  ('measurement', 'weather'),
#  ('precipitation', 'measurement'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('mitosis', 'cellbio'),
#  ('weather', 'earth'),
#  ('airmass', 'weather'),
#  ('properties of material', 'matter'),
#  ('flammable', 'properties of material'),
#  ('elec', 'energy'),
#  ('ohmslaw', 'elec'),
#  ('weather', 'earth'),
#  ('water cycle', 'weather'),
#  ('evapcond', 'water cycle'),
#  ('geo', 'earth'),
#  ('formations', 'geo'),
#  ('earth', 'formations'),
#  ('weather', 'earth'),
#  ('erosion', 'weather'),
#  ('deposition', 'erosion'),
#  ('interdependency', 'life'),
#  ('abiotic', 'interdependency'),
#  ('health', 'life'),
#  ('diesease', 'health'),
#  ('noninfect', 'diesease'),
#  ('genetic', 'noninfect'),
#  ('inner', 'earth'),
#  ('earthquakes', 'inner'),
#  ('human impacts', 'earth'),
#  ('res', 'human impacts'),
#  ('nuclear', 'res'),
#  ('environment and adaptation', 'life'),
#  ('animal adaptations', 'environment and adaptation'),
#  ('behav', 'animal adaptations'),
#  ('hunt', 'behav'),
#  ('human impacts', 'earth'),
#  ('res', 'human impacts'),
#  ('mining', 'res'),
#  ('chem', 'matter'),
#  ('chemreact', 'chem'),
#  ('functions', 'life'),
#  ('funct', 'functions'),
#  ('animaless', 'funct'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('plantcell', 'cellbio'),
#  ('properties of material', 'matter'),
#  ('eleccond', 'properties of material'),
#  ('geo', 'earth'),
#  ('fossils', 'geo'),
#  ('index', 'fossils'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('plant', 'features and functions'),
#  ('stem', 'plant'),
#  ('interdependency', 'life'),
#  ('foodchain', 'interdependency'),
#  ('sun', 'foodchain'),
#  ('fund', 'matter'),
#  ('airresistance', 'for'),
#  ('outer', 'earth'),
#  ('lith', 'outer'),
#  ('properties of material', 'matter'),
#  ('thermcond', 'properties of material'),
#  ('elec', 'energy'),
#  ('circuits', 'elec'),
#  ('energy', 'circuits'),
#  ('devices', 'energy'),
#  ('mech', 'for'),
#  ('general', 'mech'),
#  ('lunar phases', 'celestial'),
#  ('weather', 'earth'),
#  ('water cycle', 'weather'),
#  ('change of state', 'matter'),
#  ('condensing', 'change of state'),
#  ('inference', 'science'),
#  ('experiment design', 'inference'),
#  ('geo', 'earth'),
#  ('formations', 'geo'),
#  ('earth', 'formations'),
#  ('inner', 'earth'),
#  ('platevolcanoe', 'inner'),
#  ('elec', 'energy'),
#  ('electromagnets', 'elec'),
#  ('energy', 'electromagnets'),
#  ('devices', 'energy'),
#  ('features', 'celestial'),
#  ('galactic', 'features'),
#  ('waves', 'energy'),
#  ('genericprop', 'waves'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('struct', 'cellbio'),
#  ('lyso', 'struct'),
#  ('weather', 'earth'),
#  ('water cycle', 'weather'),
#  ('sun', 'water cycle'),
#  ('earth', 'sun'),
#  ('weather', 'earth'),
#  ('water cycle', 'weather'),
#  ('evapcond', 'water cycle'),
#  ('human impacts', 'earth'),
#  ('what', 'human impacts'),
#  ('globalwarming', 'what'),
#  ('interdependency', 'life'),
#  ('interdependency', 'life'),
#  ('foodchain', 'interdependency'),
#  ('decomposer', 'foodchain'),
#  ('chemistry', 'matter'),
#  ('conservation of mass', 'chemistry'),
#  ('brightness', 'celestial'),
#  ('weather', 'earth'),
#  ('wind', 'weather'),
#  ('human impacts', 'earth'),
#  ('what', 'human impacts'),
#  ('recy', 'what'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('struct', 'cellbio'),
#  ('mito', 'struct'),
#  ('energy', 'energy conversion'),
#  ('devices', 'energy'),
#  ('forces and friction', 'work'),
#  ('inference', 'science'),
#  ('inference', 'inference'),
#  ('functions', 'life'),
#  ('funct', 'functions'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('struct', 'cellbio'),
#  ('chromosome', 'struct'),
#  ('properties of material', 'matter'),
#  ('transparent', 'properties of material'),
#  ('properties of material', 'matter'),
#  ('taste', 'properties of material'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('animal', 'features and functions'),
#  ('skinintergum', 'animal'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('org', 'cellbio'),
#  ('power', 'for'),
#  ('forms', 'energy'),
#  ('mech', 'forms'),
#  ('device', 'other'),
#  ('properties of material', 'matter'),
#  ('inner', 'earth'),
#  ('internal heat', 'inner'),
#  ('states', 'matter'),
#  ('solid', 'states'),
#  ('functions', 'life'),
#  ('environmental conditions', 'functions'),
#  ('animal', 'environmental conditions'),
#  ('human impacts', 'earth'),
#  ('what', 'human impacts'),
#  ('habitat destruction', 'what'),
#  ('conservation', 'energy'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('animal', 'features and functions'),
#  ('reproduction', 'animal'),
#  ('weather', 'earth'),
#  ('water cycle', 'weather'),
#  ('sun', 'water cycle'),
#  ('interdependency', 'life'),
#  ('foodchain', 'interdependency'),
#  ('def', 'foodchain'),
#  ('reproduction', 'life'),
#  ('dna inheritance', 'reproduction'),
#  ('inheritance', 'dna inheritance'),
#  ('light', 'energy'),
#  ('speed', 'light'),
#  ('change of state', 'matter'),
#  ('melting', 'change of state'),
#  ('features', 'celestial'),
#  ('moons', 'features'),
#  ('weather', 'earth'),
#  ('erosion', 'weather'),
#  ('erosion', 'erosion'),
#  ('mixtures', 'matter'),
#  ('sephetero', 'mixtures'),
#  ('inference', 'science'),
#  ('verification', 'inference'),
#  ('devices', 'energy'),
#  ('newton', 'for'),
#  ('2nd', 'newton'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('plant', 'features and functions'),
#  ('photosynth', 'plant'),
#  ('pressure', 'for'),
#  ('weather', 'earth'),
#  ('water cycle', 'weather'),
#  ('groundwater', 'water cycle'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('animal', 'features and functions'),
#  ('circulatory', 'animal'),
#  ('eclipse', 'celestial'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('struct', 'cellbio'),
#  ('ribosomes', 'struct'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('enveff', 'matter'),
#  ('light', 'enveff'),
#  ('weather', 'earth'),
#  ('geoeff', 'weather'),
#  ('forms', 'energy'),
#  ('sound', 'forms'),
#  ('human impacts', 'earth'),
#  ('what', 'human impacts'),
#  ('pollution', 'what'),
#  ('interdependence', 'life'),
#  ('ecological features', 'interdependence'),
#  ('sizes', 'celestial'),
#  ('elec', 'energy'),
#  ('generate', 'elec'),
#  ('energy', 'generate'),
#  ('devices', 'energy'),
#  ('light', 'energy'),
#  ('scattering', 'light'),
#  ('reproduction', 'life'),
#  ('dna inheritance', 'reproduction'),
#  ('domrecess', 'dna inheritance'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('reprodother', 'cellbio'),
#  ('properties of material', 'matter'),
#  ('hard', 'properties of material'),
#  ('change of state', 'matter'),
#  ('boiling', 'change of state'),
#  ('chemistry', 'matter'),
#  ('acids and bases', 'chemistry'),
#  ('weather', 'earth'),
#  ('erosion', 'weather'),
#  ('changes', 'matter'),
#  ('physical', 'changes'),
#  ('weather', 'earth'),
#  ('erosion', 'weather'),
#  ('deposition', 'erosion'),
#  ('magnetism', 'forces'),
#  ('soil', 'earth'),
#  ('ecosystem', 'soil'),
#  ('properties of objects', 'matter'),
#  ('shape', 'properties of objects'),
#  ('functions', 'life'),
#  ('environmental response', 'functions'),
#  ('animal', 'environmental response'),
#  ('inner', 'earth'),
#  ('generic plate', 'inner'),
#  ('measurement', 'matter'),
#  ('instruments', 'measurement'),
#  ('clock', 'instruments'),
#  ('properties of objects', 'matter'),
#  ('size', 'properties of objects'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('struct', 'cellbio'),
#  ('cellmemb', 'struct'),
#  ('properties of objects', 'matter'),
#  ('mass', 'properties of objects'),
#  ('measurement', 'matter'),
#  ('unit', 'measurement'),
#  ('time', 'unit'),
#  ('properties of material', 'matter'),
#  ('flex', 'properties of material'),
#  ('changes', 'matter'),
#  ('chemical', 'changes'),
#  ('mixtures', 'matter'),
#  ('alloys', 'mixtures'),
#  ('inference', 'science'),
#  ('observation', 'inference'),
#  ('lift', 'force'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('animal', 'features and functions'),
#  ('nervous system', 'animal'),
#  ('properties of material', 'matter'),
#  ('bouy', 'properties of material'),
#  ('sound', 'energy'),
#  ('freqwl', 'sound'),
#  ('cycle', 'life'),
#  ('growth', 'cycle'),
#  ('proc', 'growth'),
#  ('chemistry', 'matter'),
#  ('atomic', 'chemistry'),
#  ('geo', 'earth'),
#  ('fossils', 'geo'),
#  ('species', 'fossils'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('animal', 'features and functions'),
#  ('breathing', 'animal'),
#  ('measurement', 'matter'),
#  ('unit', 'measurement'),
#  ('ph', 'unit'),
#  ('environment and adaptation', 'life'),
#  ('animal adaptations', 'environment and adaptation'),
#  ('struct', 'animal adaptations'),
#  ('fur', 'struct'),
#  ('environment and adaptation', 'life'),
#  ('adap', 'environment and adaptation'),
#  ('plant', 'adap'),
#  ('weather', 'earth'),
#  ('baropressure', 'weather'),
#  ('mixtures', 'matter'),
#  ('heterogeneous', 'mixtures'),
#  ('features', 'celestial'),
#  ('nebulae', 'features'),
#  ('environment and adaptation', 'life'),
#  ('animal adaptations', 'environment and adaptation'),
#  ('struct', 'animal adaptations'),
#  ('fat', 'struct'),
#  ('inner', 'earth'),
#  ('cmc', 'inner'),
#  ('crust', 'cmc'),
#  ('environment and adaptation', 'life'),
#  ('animal adaptations', 'environment and adaptation'),
#  ('behav', 'animal adaptations'),
#  ('comm', 'behav'),
#  ('features', 'celestial'),
#  ('stellar', 'features'),
#  ('interaction', 'enery'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('struct', 'cellbio'),
#  ('chloroplast', 'struct'),
#  ('environment and adaptation', 'life'),
#  ('animal adaptations', 'environment and adaptation'),
#  ('behaviours', 'animal adaptations'),
#  ('hibernation', 'behaviours'),
#  ('nitrogen cyclele', 'life'),
#  ('states', 'matter'),
#  ('gas', 'states'),
#  ('measurement', 'matter'),
#  ('unit', 'measurement'),
#  ('dist', 'unit'),
#  ('inference', 'science'),
#  ('whattesting', 'inference'),
#  ('light', 'energy'),
#  ('colincol', 'light'),
#  ('weather', 'earth'),
#  ('meas', 'weather'),
#  ('weather', 'earth'),
#  ('climate', 'weather'),
#  ('measurement', 'matter'),
#  ('instruments', 'measurement'),
#  ('balance', 'instruments'),
#  ('health', 'life'),
#  ('goodhabits', 'health'),
#  ('gravitational pull', 'celestial'),
#  ('soil', 'earth'),
#  ('components', 'soil'),
#  ('outer', 'earth'),
#  ('hydro', 'outer'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('animal', 'features and functions'),
#  ('senses', 'animal'),
#  ('inference', 'science'),
#  ('bias', 'inference'),
#  ('functions', 'life'),
#  ('environmental conditions', 'functions'),
#  ('sound', 'energy'),
#  ('genericprop', 'sound'),
#  ('carddirection', 'earth'),
#  ('properties of material', 'matter'),
#  ('durability', 'properties of material'),
#  ('human impacts', 'earth'),
#  ('res', 'human impacts'),
#  ('properties of material', 'matter'),
#  ('odor', 'properties of material'),
#  ('outer', 'earth'),
#  ('atmosphere', 'outer'),
#  ('carbon cycle', 'life'),
#  ('geo', 'earth'),
#  ('fossils', 'geo'),
#  ('reproduction', 'life'),
#  ('dna inheritance', 'reproduction'),
#  ('acquired', 'dna inheritance'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('animal', 'features and functions'),
#  ('skeletal', 'animal'),
#  ('weather', 'earth'),
#  ('clouds', 'weather'),
#  ('earth', 'clouds'),
#  ('weather', 'earth'),
#  ('water cycle', 'weather'),
#  ('evapcond', 'water cycle'),
#  ('change of state', 'matter'),
#  ('freezing', 'change of state'),
#  ('reproduction', 'life'),
#  ('dna inheritance', 'reproduction'),
#  ('mutation', 'dna inheritance'),
#  ('classification', 'life'),
#  ('cycle', 'life'),
#  ('animal cycle', 'cycle'),
#  ('livingnonliving', 'life'),
#  ('waves', 'energy'),
#  ('freqwl', 'waves'),
#  ('weather', 'earth'),
#  ('extreme', 'weather'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('plant', 'features and functions'),
#  ('reproduction', 'plant'),
#  ('seeddisp', 'reproduction'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('plant', 'features and functions'),
#  ('transpir', 'plant'),
#  ('cycle', 'life'),
#  ('growth', 'cycle'),
#  ('def', 'growth'),
#  ('human impacts', 'earth'),
#  ('res', 'human impacts'),
#  ('fossilfuel', 'res'),
#  ('forms', 'energy'),
#  ('heat', 'forms'),
#  ('properties of material', 'matter'),
#  ('luster', 'properties of material'),
#  ('waves', 'energy'),
#  ('transfereng', 'waves'),
#  ('proc', 'saf'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('struct', 'cellbio'),
#  ('nucleus', 'struct'),
#  ('sound', 'energy'),
#  ('amplitude', 'sound'),
#  ('properties of objects', 'matter'),
#  ('text', 'properties of objects'),
#  ('weather', 'earth'),
#  ('clouds', 'weather'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('animal cell', 'features and functions'),
#  ('change of state', 'matter'),
#  ('temp', 'change of state'),
#  ('human impacts', 'earth'),
#  ('res', 'human impacts'),
#  ('hydro', 'res'),
#  ('sources', 'science'),
#  ('functions', 'life'),
#  ('funct', 'functions'),
#  ('plantess', 'funct'),
#  ('features', 'celestial'),
#  ('meteor', 'features'),
#  ('reproduction', 'life'),
#  ('dna inheritance', 'reproduction'),
#  ('gendrift', 'dna inheritance'),
#  ('environment and adaptation', 'life'),
#  ('animal adaptations', 'environment and adaptation'),
#  ('behav', 'animal adaptations'),
#  ('migr', 'behav'),
#  ('apparentmotion', 'celestial'),
#  ('cycle', 'life'),
#  ('animal cycle', 'cycle'),
#  ('bird', 'animal cycle'),
#  ('spaceex', 'celestial'),
#  ('human', 'spaceex'),
#  ('meastools', 'life'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('animal', 'features and functions'),
#  ('muscular', 'animal'),
#  ('human impacts', 'earth'),
#  ('res', 'human impacts'),
#  ('soil', 'res'),
#  ('gravity', 'force'),
#  ('instruments', 'celestial'),
#  ('chem', 'matter'),
#  ('elements vs molecules and compounds', 'chem'),
#  ('human impacts', 'earth'),
#  ('res', 'human impacts'),
#  ('trees', 'res'),
#  ('thermal conductivity', 'energy'),
#  ('geo', 'earth'),
#  ('mineral', 'geo'),
#  ('formation', 'mineral'),
#  ('cycle', 'life'),
#  ('animal cycle', 'cycle'),
#  ('reptile', 'animal cycle'),
#  ('geo', 'earth'),
#  ('rock', 'geo'),
#  ('waves', 'energy'),
#  ('reflection', 'waves'),
#  ('properties of objects', 'matter'),
#  ('density', 'properties of objects'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('inner', 'earth'),
#  ('cmc', 'inner'),
#  ('mantle', 'cmc'),
#  ('properties of objects', 'matter'),
#  ('features', 'celestial'),
#  ('blackhole', 'features'),
#  ('health', 'life'),
#  ('diesease', 'health'),
#  ('pandemicepidemic', 'diesease'),
#  ('cycle', 'life'),
#  ('growth', 'cycle'),
#  ('outer', 'earth'),
#  ('atmosphere', 'outer'),
#  ('earth', 'atmosphere'),
#  ('weather', 'earth'),
#  ('water', 'weather'),
#  ('elec', 'energy'),
#  ('generate', 'elec'),
#  ('reproduction', 'life'),
#  ('sexasex', 'reproduction'),
#  ('asex', 'sexasex'),
#  ('inference', 'science'),
#  ('samplesize', 'inference'),
#  ('interdependency', 'life'),
#  ('foodchain', 'interdependency'),
#  ('consumers', 'foodchain'),
#  ('measurement', 'matter'),
#  ('instruments', 'measurement'),
#  ('compass', 'instruments'),
#  ('weather', 'earth'),
#  ('jetstream', 'weather'),
#  ('interdependency', 'life'),
#  ('foodchain ', 'interdependency'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('struct', 'cellbio'),
#  ('cellwall', 'struct'),
#  ('models', 'science'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('reprod', 'cellbio'),
#  ('environment and adaptation', 'life'),
#  ('adap', 'environment and adaptation'),
#  ('animal', 'adap'),
#  ('measurement', 'matter'),
#  ('unit', 'measurement'),
#  ('human impacts', 'earth'),
#  ('res', 'human impacts'),
#  ('wind', 'res'),
#  ('measurement', 'matter'),
#  ('instruments', 'measurement'),
#  ('magnify', 'instruments'),
#  ('health', 'life'),
#  ('diesease', 'health'),
#  ('noninfect', 'diesease'),
#  ('sound', 'energy'),
#  ('echo', 'sound'),
#  ('extinction', 'life'),
#  ('massex', 'extinction'),
#  ('states', 'matter'),
#  ('liquid', 'states'),
#  ('tides', 'celestial'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('org', 'cellbio'),
#  ('cells', 'org'),
#  ('devices', 'energy'),
#  ('heat form', 'devices'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('org', 'cellbio'),
#  ('orgsystems', 'org'),
#  ('weather', 'earth'),
#  ('models', 'weather'),
#  ('geo', 'earth'),
#  ('mineral', 'geo'),
#  ('inference', 'science'),
#  ('inference ', 'inference'),
#  ('chem', 'matter'),
#  ('endoexo', 'chem'),
#  ('light', 'energy'),
#  ('refract', 'light'),
#  ('change of state', 'matter'),
#  ('evap', 'change of state'),
#  ('environment and adaptation', 'life'),
#  ('animal adaptations', 'environment and adaptation'),
#  ('struct', 'animal adaptations'),
#  ('human impacts', 'earth'),
#  ('what', 'human impacts'),
#  ('conserve', 'what'),
#  ('inference', 'science'),
#  ('steps', 'inference'),
#  ('cycle', 'life'),
#  ('plant  cycle', 'cycle'),
#  ('measurement', 'matter'),
#  ('unit', 'measurement'),
#  ('vol', 'unit'),
#  ('interdependency', 'life'),
#  ('relspecies', 'interdependency'),
#  ('functions', 'life'),
#  ('funct', 'functions'),
#  ('animaless', 'funct'),
#  ('nutrition', 'animaless'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('animal', 'features and functions'),
#  ('inference', 'science'),
#  ('report', 'inference'),
#  ('weather', 'earth'),
#  ('measurement', 'weather'),
#  ('windspeed', 'measurement'),
#  ('forms', 'energy'),
#  ('work', 'force'),
#  ('interdependency', 'life'),
#  ('foodchain', 'interdependency'),
#  ('human impacts', 'earth'),
#  ('res', 'human impacts'),
#  ('solar', 'res'),
#  ('human impacts', 'earth'),
#  ('res', 'human impacts'),
#  ('water', 'res'),
#  ('elec', 'energy'),
#  ('cond', 'elec'),
#  ('features', 'celestial'),
#  ('planet', 'features'),
#  ('environment and adaptation', 'life'),
#  ('animal adaptations', 'environment and adaptation'),
#  ('struct', 'animal adaptations'),
#  ('senses', 'struct'),
#  ('environment and adaptation', 'life'),
#  ('plant', 'environment and adaptation'),
#  ('human impacts', 'earth'),
#  ('res', 'human impacts'),
#  ('coal', 'res'),
#  ('weather', 'earth'),
#  ('erosion', 'weather'),
#  ('weathering', 'erosion'),
#  ('states', 'matter'),
#  ('reproduction', 'life'),
#  ('sexasex', 'reproduction'),
#  ('sex', 'sexasex'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('plant', 'features and functions'),
#  ('leaf', 'plant'),
#  ('measurement', 'matter'),
#  ('instruments', 'measurement'),
#  ('graduated', 'instruments'),
#  ('properties of material', 'matter'),
#  ('specificheat', 'properties of material'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('geneexpr', 'cellbio'),
#  ('reproduction', 'life'),
#  ('forms', 'energy'),
#  ('elec', 'forms'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('respir', 'cellbio'),
#  ('inner', 'earth'),
#  ('plate', 'inner'),
#  ('mountain form', 'plate'),
#  ('inner', 'earth'),
#  ('cmc', 'inner'),
#  ('core', 'cmc'),
#  ('functions', 'life'),
#  ('features and functions', 'functions'),
#  ('cellbio', 'features and functions'),
#  ('org', 'cellbio'),
#  ('organs', 'org'),
#  ('momentum', 'for'),
#  ('geo', 'earth'),
#  ('mineral', 'geo'),
#  ('ident', 'mineral'),
#  ('enveff', 'matter'),
#  ('temp', 'enveff'),
#  ('inner', 'earth'),
#  ('plate', 'inner'),
#  ('contdrift', 'plate'),
#  ('geo', 'earth'),
#  ('rock', 'geo'),
#  ('sed', 'rock'),
#  ('human impacts', 'earth'),
#  ('res', 'human impacts'),
#  ('geothermal', 'res'),
#  ('manufacture', 'other'),
#  ('instructions', 'other'),
#  ('thermal conductivity', 'energy'),
#  ('conduct', 'thermal conductivity'),
#  ...]

# %%
print("Read {} nodes and {} edges".format( len(nodes), len(edges)) )
# Out:
# Read 402 nodes and 1059 edges

# %%
len(list(set(nodes)))
# Out:
# 402

# %%
with open("data/course_taxonomy.links.tsv","w") as fout:
    for src,dst in edges:
        fout.write("{}\t{}\n".format(src,dst))
    fout.close()
    
with open("data/course_taxonomy.nodes.txt","w") as fout:
    for node in nodes:
        fout.write("{}\n".format(node))
    fout.close()
